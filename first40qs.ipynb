# %% [markdown]
# Python Beginner Coding Test (40 Coding Questions)

# %% [markdown]
# Section A: Data Types & Basic Operations (1–10)

# %%
#1. Create a variable called name and assign it your name. Print it.
name = "Sharon"

print(name)
# Out:
# Sharon

# %%
#2. Create two integer variables and print their sum, difference, product, and division.
num = 12
num2 = 4

print(num + num2)
print(num - num2)
print(num * num2)
print(num / num2)
# Out:
# 16
# 8
# 48
# 3.0

# %%
#3. Write a program to swap two numbers without using a third variable.
x = 6
y = 90

x,y = y,x
print(x,y)
# Out:
# 90 6

# %%
#4. Write a program that takes user input for age and prints “Adult” if age ≥ 18, otherwise “Minor”.
age = int(input("Enter your age: "))
if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Adult

# %%
##Given a string "programming", print the number of times the letter 'g' appears.
word  = "programming"

print(word.count('g'))
# Out:
# 2

# %%
## Write a program that converts a given string "100" to an integer and adds 25 to it.
num2 = int("100")
print(num2 + 25)
# Out:
# 125

# %%
num3 = "100"
num4 = int(num3)

print(num4 + 25)
# Out:
# 125

# %%
## Write a program to find the largest number in the list [4, 9, 1, 7, 3].
nums = [4,9,1,7,3]

print(max(nums))
# Out:
# 9

# %%
## Write a program to reverse the list [1, 2, 3, 4, 5].
nums2 = [1,2,3,4,5]
nums2.reverse()

print(nums2)
# Out:
# [5, 4, 3, 2, 1]

# %%
## Create a dictionary with keys name, age, and country, and print the value of age.
my_dict = {"name": "Ann", "age": 40, "country": "Rwanda"}

print(my_dict)
print(my_dict["age"])
# Out:
# {'name': 'Ann', 'age': 40, 'country': 'Rwanda'}
# 40

# %%
## Write a program to convert a tuple (2, 4, 6, 8) into a list and print it.
my_tuple = (2,4,6,8)
print(list(my_tuple))
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# Section B: Conditional Statements (11–18)

# %%
## Write a program to check whether a number entered by the user is even or odd.
num5 = int(input("Enter number: "))

if num5 % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# even
